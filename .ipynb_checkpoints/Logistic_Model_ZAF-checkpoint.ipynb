# %% [markdown]
# # Setup Libraries and Enviroment

# %%
# Load necessary libraries and Account IDs
import boto3
import sagemaker
import pandas as pd

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

database_name = "insta_db"

from pyathena import connect

# %%
# Set S3 staging directory -- this is a temporary directory used for Athena queries
s3_staging_dir = "s3://{0}/athena/staging".format(bucket)

# %%
conn = connect(region_name=region, s3_staging_dir=s3_staging_dir)

# %% [markdown]
# # Organize Data for Logistic Model

# %% [raw]
# # SQL statement
# statement = """
# DROP TABLE IF EXISTS insta_db.final_parquet
# """
# import pandas as pd
#
# pd.read_sql(statement, conn)

# %% [raw]
# # SQL statement
# statement = """
# CREATE TABLE IF NOT EXISTS insta_db.final_parquet
# WITH (format = 'PARQUET', \
#         external_location = 's3://{}/parquet/final_parquet') AS
# with orders as(
# select *
# , sum(coalesce(days_since_prior_order,0)) over (partition by user_id order by order_number asc) as days
# FROM insta_db.orders_parquet
# ), products as (
# select t.*, p.product_name, d.department, a.aisle
# from (
# SELECT *
# FROM insta_db.order_products_prior_parquet
# ) t
# left join insta_db.products_parquet p
# on t.product_id = p.product_id
# left join insta_db.departments_parquet d
# on p.department_id = d.department_id
# left join insta_db.aisles_parquet a
# on p.aisle_id = a.aisle_id
# )
# select p.reordered
# , p.product_name
# , p.department
# , p.aisle
# , coalesce( days - lag(days) over (partition by o.user_id, p.product_id order by o.order_number) , 0) as days_since_previous_order
# from products p
# join orders o
# on p.order_id = o.order_id
# order by p.product_id,
# o.order_number ASC
# """.format(
#     bucket
# )
#
# import pandas as pd
#
# pd.read_sql(statement, conn)

# %%
# SQL statement
statement = """
select *
, pow(days_since_previous_order,2) as days_2
, pow(days_since_previous_order,3) as days_3
, pow(days_since_previous_order,4) as days_4
, pow(days_since_previous_order,5) as days_5
, pow(days_since_previous_order,6) as days_6
, pow(days_since_previous_order,7) as days_7
, pow(days_since_previous_order,8) as days_8
from insta_db.final_parquet limit 20000
"""

import pandas as pd

df = pd.read_sql(statement, conn)
df.head(5)
# Out:
#    reordered       product_name department             aisle  \
# 0          1  European Cucumber    produce  fresh vegetables
# 1          1  European Cucumber    produce  fresh vegetables
# 2          1  European Cucumber    produce  fresh vegetables
# 3          1  European Cucumber    produce  fresh vegetables
# 4          1  European Cucumber    produce  fresh vegetables
#
#    days_since_previous_order   days_2     days_3       days_4        days_5  \
# 0                        6.0     36.0      216.0       1296.0  7.776000e+03
# 1                        9.0     81.0      729.0       6561.0  5.904900e+04
# 2                       15.0    225.0     3375.0      50625.0  7.593750e+05
# 3                       34.0   1156.0    39304.0    1336336.0  4.543542e+07
# 4                      141.0  19881.0  2803221.0  395254161.0  5.573084e+10
#
#          days_6        days_7        days_8
# 0  4.665600e+04  2.799360e+05  1.679616e+06
# 1  5.314410e+05  4.782969e+06  4.304672e+07
# 2  1.139062e+07  1.708594e+08  2.562891e+09
# 3  1.544804e+09  5.252335e+10  1.785794e+12
# 4  7.858048e+12  1.107985e+15  1.562259e+17

# %%
# Let's Create Dummies

product = pd.get_dummies(df['product_name'],drop_first=True)

# Concatenate new columns with dummies to df

df = pd.concat([df, product], axis =1)

# %%
print(df.columns)
# Out:
# Index(['reordered', 'product_name', 'department', 'aisle',
#        'days_since_previous_order', 'days_2', 'days_3', 'days_4', 'days_5',
#        'days_6', 'days_7', 'days_8', '"Cold Remedy', '"Hemp Protein', '"Jelly',
#        '"Pancake Mix', '"Pinot Grigio', '"Waffles',
#        '24/7 Performance Cat Litter', 'Artisan Chick'n & Apple Sausage',
#        'Autumn Vegetable & Turkey Dinner with Lil' Bits Purees Dinner',
#        'Banana & Sweet Potato Organic Teething Wafers', 'Cantaloupe',
#        'Caramel Sauce', 'Chocolate Fudge Layer Cake',
#        'Coconut Chocolate Chip Energy Bar', 'Dried Sweetened Cranberries',
#        'European Cucumber', 'European Style Spring Mix',
#        'Extra Strength Melatonin Adult Gummies',
#        'Free & Clear Natural Laundry Detergent For Sensitive Skin',
#        'French Vanilla Ice Cream', 'Fresh Breath Oral Rinse Mild Mint',
#        'Fresh Scent Dishwasher Cleaner',
#        'Gluten Free Quinoa Three Cheese & Mushroom Blend', 'Honey Mustard',
#        'Honey Vanilla Greek Yogurt', 'Island Fruits Fruit Snacks',
#        'Jasmine Tea Unfiltered Ginger Ale', 'Key Lime Soda',
#        'Mint Chocolate Flavored Syrup', 'Nutter Butter Cookie Bites Go-Pak',
#        'Organic Honeycrisp Apples',
#        'Organic Red Wine & Olive Oil Dressing Organic',
#        'Organic Turkey Burgers',
#        'Organic Vegetable Greens & Greens Juice Blend',
#        'Overnight Diapers Size 6', 'Peach Mango Juice',
#        'Pizza for One Suprema  Frozen Pizza',
#        'Pomegranate Cranberry & Aloe Vera Enrich Drink', 'Rendered Duck Fat',
#        'Saline Nasal Mist', 'Small & Medium Dental Dog Treats', 'Snack Bags',
#        'Sparkling Orange Juice & Prickly Pear Beverage',
#        'Spinach Basil Garlic Linguini', 'Sweet Cooking Rice Seasoning',
#        'Ultra 7 Inch Polypropylene Traditional Plates',
#        'Vanilla with Almond Milk Iced Coffee', 'Vegetable Pot Pie',
#        'Wild Albacore Tuna No Salt Added'],
#       dtype='object')

# %% [markdown]
# # Model Logistic Regression / Propensisty Model

# %%
# Get Libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

from matplotlib import pyplot

# %%
# Check for missing values using seaborn.
sns.heatmap(df.isnull())

# %%
sns.countplot(x='reordered', data = df , palette = 'Set1').set(title= 'Number of Repurchased Products')
# Out:
# [Text(0.5, 1.0, 'Number of Repurchased Products')]

# %%
Y = pd.DataFrame(df['reordered'])
Y = Y.apply(pd.to_numeric)

X = df.drop(['reordered', 'product_name', 'department', 'aisle', 'days_6','days_7','days_8'], axis = 1)
X = X.apply(pd.to_numeric)

# %%
# Test Train Split Data 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
# Build the Model
logmodel = LogisticRegression(class_weight = 'balanced', max_iter =10000000)
logmodel.fit(X_train, y_train.values.ravel())    
predictions_log= logmodel.predict(X_test)

# %%
# Model Evaluation
print(classification_report(y_test,predictions_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2563
#            1       1.00      0.99      0.99      3437
#
#     accuracy                           0.99      6000
#    macro avg       0.99      0.99      0.99      6000
# weighted avg       0.99      0.99      0.99      6000

# %% [markdown]
# We can see that our model has a 97% precision rate for not repurchased and a 100% precision rate for repurchase.

# %%
# Feature Importance
importance = logmodel.coef_.flatten()

# %%
# Barplot of features

pyplot.rcParams["figure.figsize"]=(10,10)
pyplot.barh(X.columns,importance, color = 'g')
pyplot.title("Feature Importance")
pyplot.xlabel("Score")
pyplot.show()
